# %% [raw]
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# M2T1L1 - Introducción a Apache Spark\n",
#     "Breve notebook con ejemplos mínimos para arrancar PySpark."
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "from pyspark.sql import SparkSession\n",
#     "spark = SparkSession.builder.master('local[*]').appName('M2T1L1').getOrCreate()\n",
#     "df = spark.createDataFrame([(1,'a'),(2,'b')], ['id','val'])\n",
#     "df.show()\n",
#     "spark.stop()"
#    ]
#   }
#  ],
#  "metadata": {
#   "kernelspec": {
#    "display_name": "Python 3",
#    "language": "python",
#    "name": "python3"
#   },
#   "language_info": {
#    "name": "python",
#    "version": "3.x"
#   }
#  },
#  "nbformat": 4,
#  "nbformat_minor": 5
# }
