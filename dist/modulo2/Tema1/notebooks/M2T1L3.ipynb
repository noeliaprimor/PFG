# %% [raw]
# {
#  "cells": [
#   {"cell_type": "markdown", "metadata": {}, "source": ["# M2T1L3 - Tipos de gestores de clústeres\nComparativa rápida: Standalone, YARN, Mesos, Kubernetes."]},
#   {"cell_type": "code", "execution_count": null, "metadata": {}, "outputs": [], "source": ["print('Gestores de clúster: Standalone, YARN, Kubernetes')"]}
#  ], "metadata": {"kernelspec": {"display_name": "Python 3","language": "python","name": "python3"}, "language_info": {"name": "python"}}, "nbformat": 4, "nbformat_minor": 5}
