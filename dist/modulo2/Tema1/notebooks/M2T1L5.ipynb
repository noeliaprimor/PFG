# %% [raw]
# { "cells": [{ "cell_type": "markdown", "metadata": {}, "source": ["# M2T1L5 - Instalación y configuración\nInstrucciones y comprobaciones básicas."]}, { "cell_type": "code", "execution_count": null, "metadata": {}, "outputs": [], "source": ["# No es habitual ejecutar instalación desde notebook; usar terminal\nprint('Sigue las instrucciones en la lección para instalar Spark')"]} ], "metadata": {"kernelspec": {"display_name": "Python 3","language": "python","name": "python3"}, "language_info": {"name": "python"}}, "nbformat": 4, "nbformat_minor": 5 }
