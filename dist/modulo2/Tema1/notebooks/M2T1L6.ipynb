# %% [raw]
# { "cells": [{ "cell_type": "markdown", "metadata": {}, "source": ["# M2T1L6 - Uso de shells Spark\nEjemplos interactivos con spark-shell y pyspark."]}, { "cell_type": "code", "execution_count": null, "metadata": {}, "outputs": [], "source": ["# Ejemplo PySpark repl no disponible aquí\nprint('Usar pyspark --master local[*]')"]} ], "metadata": {"kernelspec": {"display_name": "Python 3","language": "python","name": "python3"}, "language_info": {"name": "python"}}, "nbformat": 4, "nbformat_minor": 5 }
