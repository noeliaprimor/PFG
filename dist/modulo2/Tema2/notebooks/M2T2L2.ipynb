# %% [raw]
# { "cells": [{ "cell_type": "markdown", "metadata": {}, "source": ["# M2T2L2 - Desarrollo y ejecución de una aplicación Spark\nEjemplo: estructura mínima de un proyecto PySpark."]}, { "cell_type": "code", "execution_count": null, "metadata": {}, "outputs": [], "source": ["from pyspark.sql import SparkSession\n\nif __name__ == '__main__':\n    spark = SparkSession.builder.appName('M2T2L2').getOrCreate()\n    df = spark.createDataFrame([(1,'x'),(2,'y')], ['id','val'])\n    df.show()\n    spark.stop()\n"]}], "metadata": {"kernelspec": {"display_name": "Python 3","language": "python","name": "python3"}, "language_info": {"name": "python"}}, "nbformat": 4, "nbformat_minor": 5 }
