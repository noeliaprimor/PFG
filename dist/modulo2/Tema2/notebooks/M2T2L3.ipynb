# %% [raw]
# { "cells": [{ "cell_type": "markdown", "metadata": {}, "source": ["# M2T2L3 - SparkSession y SparkContext\nEjemplos de creación y diferencias."]}, { "cell_type": "code", "execution_count": null, "metadata": {}, "outputs": [], "source": ["from pyspark.sql import SparkSession\n# SparkSession encapsula SparkContext\nspark = SparkSession.builder.appName('M2T2L3').getOrCreate()\nsc = spark.sparkContext\nprint(sc.master)\nspark.stop()\n"]}], "metadata": {"kernelspec": {"display_name": "Python 3","language": "python","name": "python3"}, "language_info": {"name": "python"}}, "nbformat": 4, "nbformat_minor": 5 }
