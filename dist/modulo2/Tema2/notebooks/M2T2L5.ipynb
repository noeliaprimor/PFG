# %% [raw]
# { "cells": [{ "cell_type": "markdown", "metadata": {}, "source": ["# M2T2L5 - Cargar y guardar datos en Spark\nEjemplo: lectura/escritura CSV/Parquet con PySpark."]}, { "cell_type": "code", "execution_count": null, "metadata": {}, "outputs": [], "source": ["from pyspark.sql import SparkSession\nss = SparkSession.builder.appName('M2T2L5').getOrCreate()\ndf = ss.createDataFrame([(1,'a'),(2,'b')], ['id','val'])\ndf.write.mode('overwrite').parquet('/tmp/example.parquet')\ndf2 = ss.read.parquet('/tmp/example.parquet')\ndf2.show()\nss.stop()"]}], "metadata": {"kernelspec": {"display_name": "Python 3","language": "python","name": "python3"}, "language_info": {"name": "python"}}, "nbformat": 4, "nbformat_minor": 5 }
