# %% [raw]
# { "cells": [{ "cell_type": "markdown", "metadata": {}, "source": ["# M2T2L6 - RDD, DataFrame y Dataset\nEjemplo comparativo de RDD vs DataFrame."]}, { "cell_type": "code", "execution_count": null, "metadata": {}, "outputs": [], "source": ["from pyspark.sql import SparkSession\nss = SparkSession.builder.appName('M2T2L6').getOrCreate()\nsc = ss.sparkContext\nrdd = sc.parallelize([('a',1),('b',2)])\ndf = ss.createDataFrame(rdd, ['k','v'])\ndf.show()\nss.stop()"]}], "metadata": {"kernelspec": {"display_name": "Python 3","language": "python","name": "python3"}, "language_info": {"name": "python"}}, "nbformat": 4, "nbformat_minor": 5 }
