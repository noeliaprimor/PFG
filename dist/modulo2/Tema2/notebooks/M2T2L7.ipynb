# %% [raw]
# { "cells": [{ "cell_type": "markdown", "metadata": {}, "source": ["# M2T2L7 - Paralelización y particionado\nEjemplo de repartition/coalesce y su efecto en performance."]}, { "cell_type": "code", "execution_count": null, "metadata": {}, "outputs": [], "source": ["from pyspark.sql import SparkSession\nss = SparkSession.builder.appName('M2T2L7').getOrCreate()\ndf = ss.range(0,1000000)\ndf2 = df.repartition(8)\nprint('partitions', df.rdd.getNumPartitions(), df2.rdd.getNumPartitions())\nss.stop()"]}], "metadata": {"kernelspec": {"display_name": "Python 3","language": "python","name": "python3"}, "language_info": {"name": "python"}}, "nbformat": 4, "nbformat_minor": 5 }
