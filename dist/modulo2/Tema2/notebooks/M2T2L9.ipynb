# %% [raw]
# { "cells": [{ "cell_type": "markdown", "metadata": {}, "source": ["# M2T2L9 - Optimizaciones sobre DataFrames\nUso de cache, persist, broadcast, explain()."]}, { "cell_type": "code", "execution_count": null, "metadata": {}, "outputs": [], "source": ["from pyspark.sql import SparkSession\nss = SparkSession.builder.appName('M2T2L9').getOrCreate()\ndf = ss.range(1000000)\ndf.cache()\ndf.count()\nprint('cached')\nss.stop()"]}], "metadata": {"kernelspec": {"display_name": "Python 3","language": "python","name": "python3"}, "language_info": {"name": "python"}}, "nbformat": 4, "nbformat_minor": 5 }
