# %% [raw]
# { "cells": [{ "cell_type": "markdown", "metadata": {}, "source": ["# M2T3L1 - Librerías disponibles en Spark\nResumen y ejemplos: Spark SQL, MLlib, GraphX, Structured Streaming."]}, { "cell_type": "code", "execution_count": null, "metadata": {}, "outputs": [], "source": ["from pyspark.sql import SparkSession\nspark = SparkSession.builder.appName('M2T3L1').getOrCreate()\nprint('Spark', spark.version)\nspark.stop()"]}], "metadata": {"kernelspec": {"display_name": "Python 3","language": "python","name": "python3"}, "language_info": {"name": "python"}}, "nbformat": 4, "nbformat_minor": 5 }
