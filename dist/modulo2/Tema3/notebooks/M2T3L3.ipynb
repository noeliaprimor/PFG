# %% [raw]
# { "cells": [{ "cell_type": "markdown", "metadata": {}, "source": ["# M2T3L3 - GraphX (introducción)\nEjemplos simples de grafos (nota: GraphX es Scala-centric)" ]}, { "cell_type": "code", "execution_count": null, "metadata": {}, "outputs": [], "source": ["print('GraphX es típicamente usado desde Scala; ver ejemplos en la documentación')"]}], "metadata": {"kernelspec": {"display_name": "Python 3","language": "python","name": "python3"}, "language_info": {"name": "python"}}, "nbformat": 4, "nbformat_minor": 5 }
