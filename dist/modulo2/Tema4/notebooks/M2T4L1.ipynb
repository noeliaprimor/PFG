# %% [raw]
# { "cells": [{ "cell_type": "markdown", "metadata": {}, "source": ["# M2T4L1 - Monitorización y configuración de Spark\nEjemplos: métricas, interfaz Web UI y configuración de logs."]}, { "cell_type": "code", "execution_count": null, "metadata": {}, "outputs": [], "source": ["print('Revisar Spark UI en http://<driver-host>:4040 cuando la aplicación está corriendo')"]}], "metadata": {"kernelspec": {"display_name": "Python 3","language": "python","name": "python3"}, "language_info": {"name": "python"}}, "nbformat": 4, "nbformat_minor": 5 }
