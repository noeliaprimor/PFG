# %% [raw]
# { "cells": [{ "cell_type": "markdown", "metadata": {}, "source": ["# M2T4L2 - Seguridad y despliegue\nNotas sobre autenticación, autorizaciones y empaquetado para despliegue."]}, { "cell_type": "code", "execution_count": null, "metadata": {}, "outputs": [], "source": ["print('Configura kerberos, TLS y políticas de acceso según tu entorno')"]}], "metadata": {"kernelspec": {"display_name": "Python 3","language": "python","name": "python3"}, "language_info": {"name": "python"}}, "nbformat": 4, "nbformat_minor": 5 }
