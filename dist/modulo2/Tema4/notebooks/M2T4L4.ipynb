# %% [raw]
# { "cells": [{ "cell_type": "markdown", "metadata": {}, "source": ["# M2T4L4 - Recursos y lecturas sobre monitorización/despliegue\nEnlaces útiles y herramientas (Ganglia, Prometheus, Grafana, Spark UI)."]}], "metadata": {"kernelspec": {"display_name": "Python 3","language": "python","name": "python3"}, "language_info": {"name": "python"}}, "nbformat": 4, "nbformat_minor": 5 }
