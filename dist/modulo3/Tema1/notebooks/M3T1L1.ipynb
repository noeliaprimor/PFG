# %% [raw]
# { "cells": [{ "cell_type": "markdown", "metadata": {}, "source": ["# M3T1L1 - Introducción a procesamiento en tiempo real\nNotebook introductorio con ejemplos conceptuales de streaming."]}, { "cell_type": "code", "execution_count": null, "metadata": {}, "outputs": [], "source": ["print('Este notebook contiene ejemplos conceptuales para procesado en tiempo real (Structured Streaming).')"]}], "metadata": {"kernelspec": {"display_name": "Python 3","language": "python","name": "python3"}, "language_info": {"name": "python"}}, "nbformat": 4, "nbformat_minor": 5 }
