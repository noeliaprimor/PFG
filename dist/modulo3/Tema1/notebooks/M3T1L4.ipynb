# %% [raw]
# { "cells": [{ "cell_type": "markdown", "metadata": {}, "source": ["# M3T1L4 - Introducción a Spark Streaming\nEjemplo sencillo de Structured Streaming leyendo de Kafka y escribiendo en console (conceptual)."]}, { "cell_type": "code", "execution_count": null, "metadata": {}, "outputs": [], "source": ["print('Ejemplo conceptual: spark.readStream.format(\"kafka\") ...')"]}], "metadata": {"kernelspec": {"display_name": "Python 3","language": "python","name": "python3"}, "language_info": {"name": "python"}}, "nbformat": 4, "nbformat_minor": 5 }
