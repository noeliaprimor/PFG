# %% [raw]
# { "cells": [{ "cell_type": "markdown", "metadata": {}, "source": ["# M3T2L1 - Adquisición y transmisión de eventos\nConceptos sobre productores, brokers y particionado de topics."]}, { "cell_type": "code", "execution_count": null, "metadata": {}, "outputs": [], "source": ["print('Producer/Consumer ejemplos conceptuales')"]}], "metadata": {"kernelspec": {"display_name": "Python 3","language": "python","name": "python3"}, "language_info": {"name": "python"}}, "nbformat": 4, "nbformat_minor": 5 }
