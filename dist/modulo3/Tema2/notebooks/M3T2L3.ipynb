# %% [raw]
# { "cells": [{ "cell_type": "markdown", "metadata": {}, "source": ["# M3T2L3 - Sinks y conectores\nIntroducción a Kafka Connect y sinks comunes (HDFS, S3, Elasticsearch)."]}, { "cell_type": "code", "execution_count": null, "metadata": {}, "outputs": [], "source": ["print('Kafka Connect connectors: S3, HDFS, Elasticsearch examples')"]}], "metadata": {"kernelspec": {"display_name": "Python 3","language": "python","name": "python3"}, "language_info": {"name": "python"}}, "nbformat": 4, "nbformat_minor": 5 }
