# %% [raw]
# { "cells": [{ "cell_type": "markdown", "metadata": {}, "source": ["# M3T3L1 - Spark Streaming\nEjemplo de uso de Structured Streaming con Kafka como fuente (conceptual)."]}, { "cell_type": "code", "execution_count": null, "metadata": {}, "outputs": [], "source": ["print('spark.readStream.format(\"kafka\") example')"]}], "metadata": {"kernelspec": {"display_name": "Python 3","language": "python","name": "python3"}, "language_info": {"name": "python"}}, "nbformat": 4, "nbformat_minor": 5 }
