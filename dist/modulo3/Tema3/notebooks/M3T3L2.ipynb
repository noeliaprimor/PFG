# %% [raw]
# { "cells": [{ "cell_type": "markdown", "metadata": {}, "source": ["# M3T3L2 - Integración con Kafka\nDetalles de integración y ejemplos de lectura/escritura entre Spark y Kafka."]}, { "cell_type": "code", "execution_count": null, "metadata": {}, "outputs": [], "source": ["print('integración Spark <-> Kafka ejemplos conceptuales')"]}], "metadata": {"kernelspec": {"display_name": "Python 3","language": "python","name": "python3"}, "language_info": {"name": "python"}}, "nbformat": 4, "nbformat_minor": 5 }
