# %% [raw]
# { "cells": [{ "cell_type": "markdown", "metadata": {}, "source": ["# M3T3L3 - Casos prácticos con Spark Streaming\nEjemplos: agregaciones por ventana, joins con estados y sinks." ]}, { "cell_type": "code", "execution_count": null, "metadata": {}, "outputs": [], "source": ["print('Window aggregations, stateful processing examples')"]}], "metadata": {"kernelspec": {"display_name": "Python 3","language": "python","name": "python3"}, "language_info": {"name": "python"}}, "nbformat": 4, "nbformat_minor": 5 }
